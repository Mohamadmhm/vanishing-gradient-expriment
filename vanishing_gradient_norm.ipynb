# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

# %matplotlib inline

# %%
#dataset = datasets.load_iris()
#dataset = datasets.load_boston()
dataset = datasets.load_breast_cancer()
X=dataset.data
y=dataset.target.reshape(-1, 1)

encoder = OneHotEncoder(sparse=False)
y = encoder.fit_transform(y)
classes=y.shape[1]
y=dataset.target.reshape(-1, 1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)
X_train.shape,X_test.shape,y_train.shape,y_test.shape,classes
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ((512, 30), (57, 30), (512, 1), (57, 1), 2)

# %%
X_train = torch.FloatTensor(X_train)
X_test = torch.FloatTensor(X_test)
y_train = torch.LongTensor(y_train)
y_test = torch.LongTensor(y_test)

# %%
class Model1(nn.Module):
    def __init__(self,input_dim,output_dim,num_layers):
        super(Model1,self).__init__()
        self.input_layer   = nn.Linear(input_dim,5)
        self.hidden=nn.Sequential()
        for i in  range(num_layers-1) :

            self.hidden.add_module("hidden_layer"+str(i), nn.Linear(5,5))
            self.hidden.add_module("ActiveF"+str(i),nn.ReLU())

        self.output_layer   = nn.Linear(5,output_dim)

        #self.softmax = nn.Softmax(dim=-1)

        self.activefunction = nn.ReLU()
    def forward(self,x):
            out = self.input_layer(x)
            out=self.activefunction(out)
            out=self.hidden(out)
            out = self.output_layer(out)
            #out = self.softmax(out)
            return out


class Model3(nn.Module):
    def __init__(self,input_dim,output_dim,num_layers):
        super(Model3,self).__init__()
        self.input_layer= nn.Linear(input_dim,5)
        self.bn=nn.BatchNorm1d(5)
        self.hidden=nn.Sequential()
        for i in  range(num_layers-1) :

            self.hidden.add_module("hidden_layer"+str(i), nn.Linear(5,5))
            self.hidden.add_module("BN"+str(i),nn.BatchNorm1d(5))
            self.hidden.add_module("ActiveF"+str(i),nn.ReLU())

        self.output_layer   = nn.Linear(5,output_dim)

        #self.softmax = nn.Softmax(dim=-1)

        self.activefunction = nn.ReLU()

    def forward(self,x):
            out = self.input_layer(x)
            out = self.bn(out)
            out=self.activefunction(out)
            out=self.hidden(out)
            #print(out.shape)
            out = self.output_layer(out)
            #out = self.softmax(out)
            return out

class Model4(nn.Module):
    def __init__(self,input_dim,output_dim,num_layers):
        super(Model4,self).__init__()
        self.input_layer= nn.Linear(input_dim,5)
        self.bn=nn.BatchNorm1d(5)
        self.hidden=nn.Sequential()
        for i in  range(num_layers-1) :

            self.hidden.add_module("hidden_layer"+str(i), nn.Linear(5,5))
            self.hidden.add_module("BN"+str(i),nn.BatchNorm1d(5))
            self.hidden.add_module("ActiveF"+str(i),nn.Sigmoid())

        self.output_layer   = nn.Linear(5,output_dim)

        #self.softmax = nn.Softmax(dim=-1)

        self.activefunction = nn.Sigmoid()

    def forward(self,x):

            out = self.input_layer(x)
            out = self.bn(out)
            out=self.activefunction(out)
            out=self.hidden(out)
            #print(out.shape)
            out = self.output_layer(out)
            #out = self.softmax(out)
            return out

class Model2(nn.Module):
    def __init__(self,input_dim,output_dim,num_layers):
        super(Model2,self).__init__()
        self.input_layer   = nn.Linear(input_dim,5)
        self.hidden=nn.Sequential()
        for i in  range(num_layers-1) :

            self.hidden.add_module("hidden_layer"+str(i), nn.Linear(5,5))
            self.hidden.add_module("ActiveF"+str(i),nn.Sigmoid())

        self.output_layer   = nn.Linear(5,output_dim)

        #self.softmax = nn.Softmax(dim=-1)

        self.activefunction = nn.Sigmoid()
    def forward(self,x):
            out = self.input_layer(x)
            out=self.activefunction(out)
            out=self.hidden(out)
            out = self.output_layer(out)
            #out = self.softmax(out)
            return out

# %%
from torchsummary import summary



device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = Model1(3,1,num_layers=5).to(device)
summary(model,(256,256,3),1 ,"cuda")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = Model2(3,1,num_layers=5).to(device)
summary(model,(256,256,3),1 ,"cuda")
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1           [1, 256, 256, 5]              20
#               ReLU-2           [1, 256, 256, 5]               0
#             Linear-3           [1, 256, 256, 5]              30
#               ReLU-4           [1, 256, 256, 5]               0
#             Linear-5           [1, 256, 256, 5]              30
#               ReLU-6           [1, 256, 256, 5]               0
#             Linear-7           [1, 256, 256, 5]              30
#               ReLU-8           [1, 256, 256, 5]               0
#             Linear-9           [1, 256, 256, 5]              30
#              ReLU-10           [1, 256, 256, 5]               0
#            Linear-11           [1, 256, 256, 1]               6
# ================================================================
# Total params: 146
# Trainable params: 146
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.75
# Forward/backward pass size (MB): 25.50
# Params size (MB): 0.00
# Estimated Total Size (MB): 26.25
# ----------------------------------------------------------------
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1           [1, 256, 256, 5]              20
#            Sigmoid-2           [1, 256, 256, 5]               0
#             Linear-3           [1, 256, 256, 5]              30
#            Sigmoid-4           [1, 256, 256, 5]               0
#             Linear-5           [1, 256, 256, 5]              30
#            Sigmoid-6           [1, 256, 256, 5]               0
#             Linear-7           [1, 256, 256, 5]              30
#            Sigmoid-8           [1, 256, 256, 5]               0
#             Linear-9           [1, 256, 256, 5]              30
#           Sigmoid-10           [1, 256, 256, 5]               0
#            Linear-11           [1, 256, 256, 1]               6
# ================================================================
# Total params: 146
# Trainable params: 146
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.75
# Forward/backward pass size (MB): 25.50
# Params size (MB): 0.00
# Estimated Total Size (MB): 26.25
# ----------------------------------------------------------------

# %%
from numpy import dtype
def train(num_layers,Loss,data,num_epochs=100,model=Model1,showepochs=1,classes=2):
    X_train,y_train,X_test,y_test = data


    input_dim  = X_train.shape[-1]
    output_dim = classes
    model = model(input_dim,output_dim,num_layers)
    optimizer = torch.optim.Adam(model.parameters(),lr=0.001)
    train_losses = []
    test_losses  = []
    train_acc=[]
    test_acc=[]
    y_train=y_train.squeeze(1)
    y_test=y_test.squeeze(1)

    for epoch in range(num_epochs):
        model.train()
        output_train = model(X_train)

        #print(output_train.shape,X_train.shape,y_train.shape)
        loss_train = Loss(output_train, y_train)
        acc_train = (torch.argmax(output_train, dim=1) == y_train).float().mean()
        #output = (output_train>0.5).float()
        #print(output_train,y_train)
        #acc_train = (output == y_train).float().mean()
        optimizer.zero_grad()
        loss_train.backward()

        optimizer.step()


        with torch.no_grad():
          model.eval()
          output_test = model(X_test)

          loss_test = Loss(output_test,y_test)
          acc_test = (torch.argmax(output_test, dim=1) == y_test).float().mean()
          #output = (output_test>0.5).float()
          #acc_test = (output == y_test).float().mean()


        train_losses.append(loss_train.item())
        test_losses.append(loss_test.item())
        train_acc.append(acc_train.item())
        test_acc.append(acc_test.item())
        if showepochs==1 :
          if (epoch+1) % 50 == 0:
            print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {loss_train.item():.4f}, Test Loss: {loss_test.item():.4f}, Train ACCuracy: {acc_train.item():.4f}, Test Accuracy: {acc_test.item():.4f}")



    return train_losses , test_losses , train_acc, test_acc , model

# %%
num_epochs=50
LOSS=nn.CrossEntropyLoss()

max=20
##########################################
Active_Function=nn.ReLU()
print('with ',Active_Function,' active faunction:')
#################
for num_layers in range(1,max+1,1):
  q=[]
  train_losses , test_losses,  train_acc , test_acc  , model  = train(num_layers,LOSS,(X_train,y_train,X_test,y_test),num_epochs,model=Model1,showepochs=0,classes=classes)

  print('network number' ,num_layers, " : \n")

  print(' layer 0', torch.norm(model.input_layer.weight.grad))

  for j in range(1,num_layers,1):

    r="model.hidden."+"hidden_layer"+str(j-1)+".weight.grad"
    print(' layer ',j, torch.norm(eval(r)))

  print(' layer ',num_layers,torch.norm(model.output_layer.weight.grad))

#for p in model.parameters():
# torch.norm(p.grad)

###############################################################
Active_Function=nn.Sigmoid()
print('with ',Active_Function,' active faunction:')
###################
for num_layers in range(1,max+1,1):

  train_losses , test_losses,  train_acc , test_acc  , model  = train(num_layers,LOSS,(X_train,y_train,X_test,y_test),num_epochs,model=Model3,showepochs=0,classes=classes)

  print('network number' ,num_layers, " : \n")

  print(' layer 0', torch.norm(model.input_layer.weight.grad))
  q.append
  for j in range(1,num_layers,1):

    r="model.hidden."+"hidden_layer"+str(j-1)+".weight.grad"
    print(' layer ',j, torch.norm(eval(r)))

  print(' layer ',num_layers,torch.norm(model.output_layer.weight.grad))
# Out:
# with  ReLU()  active faunction:
# network number 1  :
#
#  layer 0 tensor(78.4073)
#  layer  1 tensor(47.0155)
# network number 2  :
#
#  layer 0 tensor(1.1224)
#  layer  1 tensor(3.3314)
#  layer  2 tensor(2.0711)
# network number 3  :
#
#  layer 0 tensor(9.3815)
#  layer  1 tensor(3.8643)
#  layer  2 tensor(1.3978)
#  layer  3 tensor(1.2998)
# network number 4  :
#
#  layer 0 tensor(0.4004)
#  layer  1 tensor(0.2198)
#  layer  2 tensor(0.2016)
#  layer  3 tensor(0.2800)
#  layer  4 tensor(0.4968)
# network number 5  :
#
#  layer 0 tensor(0.1621)
#  layer  1 tensor(0.0969)
#  layer  2 tensor(0.0774)
#  layer  3 tensor(0.0414)
#  layer  4 tensor(0.0944)
#  layer  5 tensor(0.1174)
# network number 6  :
#
#  layer 0 tensor(0.0486)
#  layer  1 tensor(0.0173)
#  layer  2 tensor(0.0082)
#  layer  3 tensor(0.0256)
#  layer  4 tensor(0.0203)
#  layer  5 tensor(0.0353)
#  layer  6 tensor(0.0808)
# network number 7  :
#
#  layer 0 tensor(0.2721)
#  layer  1 tensor(0.0393)
#  layer  2 tensor(0.0309)
#  layer  3 tensor(0.0673)
#  layer  4 tensor(0.0425)
#  layer  5 tensor(0.0308)
#  layer  6 tensor(0.0675)
#  layer  7 tensor(0.1099)
# network number 8  :
#
#  layer 0 tensor(0.0072)
#  layer  1 tensor(0.0082)
#  layer  2 tensor(0.0038)
#  layer  3 tensor(0.0042)
#  layer  4 tensor(0.0019)
#  layer  5 tensor(0.0051)
#  layer  6 tensor(0.0056)
#  layer  7 tensor(0.0261)
#  layer  8 tensor(0.0165)
# network number 9  :
#
#  layer 0 tensor(0.0005)
#  layer  1 tensor(0.0002)
#  layer  2 tensor(0.0004)
#  layer  3 tensor(0.0004)
#  layer  4 tensor(0.0013)
#  layer  5 tensor(0.0015)
#  layer  6 tensor(0.0010)
#  layer  7 tensor(0.0018)
#  layer  8 tensor(0.0008)
#  layer  9 tensor(0.0005)
# network number 10  :
#
#  layer 0 tensor(0.0055)
#  layer  1 tensor(0.0013)
#  layer  2 tensor(0.0033)
#  layer  3 tensor(0.0021)
#  layer  4 tensor(0.0046)
#  layer  5 tensor(0.0054)
#  layer  6 tensor(0.0106)
#  layer  7 tensor(0.0313)
#  layer  8 tensor(0.0326)
#  layer  9 tensor(0.0616)
#  layer  10 tensor(0.1031)
# network number 11  :
#
#  layer 0 tensor(0.)
#  layer  1 tensor(0.)
#  layer  2 tensor(0.)
#  layer  3 tensor(0.)
#  layer  4 tensor(0.)
#  layer  5 tensor(0.)
#  layer  6 tensor(0.)
#  layer  7 tensor(0.)
#  layer  8 tensor(0.)
#  layer  9 tensor(4.4041e-06)
#  layer  10 tensor(3.8896e-05)
#  layer  11 tensor(0.0002)
# network number 12  :
#
#  layer 0 tensor(0.0052)
#  layer  1 tensor(0.0021)
#  layer  2 tensor(0.0023)
#  layer  3 tensor(0.0018)
#  layer  4 tensor(0.0042)
#  layer  5 tensor(0.0028)
#  layer  6 tensor(0.0041)
#  layer  7 tensor(0.0090)
#  layer  8 tensor(0.0072)
#  layer  9 tensor(0.0236)
#  layer  10 tensor(0.0174)
#  layer  11 tensor(0.0234)
#  layer  12 tensor(0.0658)
# network number 13  :
#
#  layer 0 tensor(0.)
#  layer  1 tensor(0.)
#  layer  2 tensor(0.)
#  layer  3 tensor(0.)
#  layer  4 tensor(0.)
#  layer  5 tensor(0.)
#  layer  6 tensor(0.)
#  layer  7 tensor(0.)
#  layer  8 tensor(0.)
#  layer  9 tensor(0.)
#  layer  10 tensor(0.)
#  layer  11 tensor(0.)
#  layer  12 tensor(0.)
#  layer  13 tensor(0.0831)
# network number 14  :
#
#  layer 0 tensor(0.)
#  layer  1 tensor(0.)
#  layer  2 tensor(0.)
#  layer  3 tensor(0.)
#  layer  4 tensor(3.2966e-06)
#  layer  5 tensor(1.2386e-05)
#  layer  6 tensor(2.8199e-05)
#  layer  7 tensor(9.6454e-05)
#  layer  8 tensor(0.0002)
#  layer  9 tensor(0.0005)
#  layer  10 tensor(0.0025)
#  layer  11 tensor(0.0072)
#  layer  12 tensor(0.0104)
#  layer  13 tensor(0.0351)
#  layer  14 tensor(0.0836)
# network number 15  :
#
#  layer 0 tensor(0.0003)
#  layer  1 tensor(0.0002)
#  layer  2 tensor(0.0001)
#  layer  3 tensor(8.6499e-05)
#  layer  4 tensor(0.0001)
#  layer  5 tensor(8.0292e-05)
#  layer  6 tensor(7.0622e-05)
#  layer  7 tensor(8.1421e-05)
#  layer  8 tensor(0.0002)
#  layer  9 tensor(0.0004)
#  layer  10 tensor(0.0003)
#  layer  11 tensor(0.0004)
#  layer  12 tensor(0.0007)
#  layer  13 tensor(0.0015)
#  layer  14 tensor(0.0051)
#  layer  15 tensor(0.0063)
# network number 16  :
#
#  layer 0 tensor(0.)
#  layer  1 tensor(0.)
#  layer  2 tensor(0.)
#  layer  3 tensor(0.)
#  layer  4 tensor(0.)
#  layer  5 tensor(0.)
#  layer  6 tensor(0.)
#  layer  7 tensor(0.)
#  layer  8 tensor(0.)
#  layer  9 tensor(0.)
#  layer  10 tensor(0.)
#  layer  11 tensor(0.)
#  layer  12 tensor(0.)
#  layer  13 tensor(0.)
#  layer  14 tensor(0.)
#  layer  15 tensor(0.)
#  layer  16 tensor(0.)
# network number 17  :
#
#  layer 0 tensor(1.1320e-05)
#  layer  1 tensor(4.7844e-06)
#  layer  2 tensor(2.5707e-06)
#  layer  3 tensor(1.9393e-06)
#  layer  4 tensor(2.5814e-06)
#  layer  5 tensor(4.0811e-06)
#  layer  6 tensor(1.1779e-05)
#  layer  7 tensor(1.0180e-05)
#  layer  8 tensor(1.0423e-05)
#  layer  9 tensor(0.0004)
#  layer  10 tensor(0.0007)
#  layer  11 tensor(0.0014)
#  layer  12 tensor(0.0041)
#  layer  13 tensor(0.0047)
#  layer  14 tensor(0.0059)
#  layer  15 tensor(0.0303)
#  layer  16 tensor(0.0612)
#  layer  17 tensor(0.0567)
# network number 18  :
#
#  layer 0 tensor(5.7633e-07)
#  layer  1 tensor(2.7255e-07)
#  layer  2 tensor(2.5382e-07)
#  layer  3 tensor(1.2114e-07)
#  layer  4 tensor(1.8093e-07)
#  layer  5 tensor(3.1580e-07)
#  layer  6 tensor(3.4537e-07)
#  layer  7 tensor(3.5093e-07)
#  layer  8 tensor(4.0766e-07)
#  layer  9 tensor(4.2525e-06)
#  layer  10 tensor(1.2615e-05)
#  layer  11 tensor(3.7581e-05)
#  layer  12 tensor(0.0001)
#  layer  13 tensor(0.0004)
#  layer  14 tensor(0.0018)
#  layer  15 tensor(0.0041)
#  layer  16 tensor(0.0265)
#  layer  17 tensor(0.0287)
#  layer  18 tensor(0.1846)
# network number 19  :
#
#  layer 0 tensor(0.)
#  layer  1 tensor(0.)
#  layer  2 tensor(0.)
#  layer  3 tensor(0.)
#  layer  4 tensor(0.)
#  layer  5 tensor(0.)
#  layer  6 tensor(0.)
#  layer  7 tensor(0.)
#  layer  8 tensor(0.)
#  layer  9 tensor(0.)
#  layer  10 tensor(0.)
#  layer  11 tensor(0.)
#  layer  12 tensor(0.)
#  layer  13 tensor(0.)
#  layer  14 tensor(0.)
#  layer  15 tensor(0.)
#  layer  16 tensor(0.)
#  layer  17 tensor(0.)
#  layer  18 tensor(0.)
#  layer  19 tensor(0.)
# network number 20  :
#
#  layer 0 tensor(0.)
#  layer  1 tensor(0.)
#  layer  2 tensor(0.)
#  layer  3 tensor(0.)
#  layer  4 tensor(0.)
#  layer  5 tensor(0.)
#  layer  6 tensor(0.)
#  layer  7 tensor(0.)
#  layer  8 tensor(0.)
#  layer  9 tensor(0.)
#  layer  10 tensor(0.)
#  layer  11 tensor(0.)
#  layer  12 tensor(0.)
#  layer  13 tensor(0.)
#  layer  14 tensor(6.7644e-05)
#  layer  15 tensor(0.0003)
#  layer  16 tensor(0.0013)
#  layer  17 tensor(0.0040)
#  layer  18 tensor(0.0067)
#  layer  19 tensor(0.0435)
#  layer  20 tensor(0.0686)
# with  Sigmoid()  active faunction:
# network number 1  :
#
#  layer 0 tensor(0.0418)
#  layer  1 tensor(0.5491)
# network number 2  :
#
#  layer 0 tensor(0.1733)
#  layer  1 tensor(0.6288)
#  layer  2 tensor(0.3357)
# network number 3  :
#
#  layer 0 tensor(0.0463)
#  layer  1 tensor(0.0911)
#  layer  2 tensor(0.1555)
#  layer  3 tensor(0.2712)
# network number 4  :
#
#  layer 0 tensor(0.0760)
#  layer  1 tensor(0.1161)
#  layer  2 tensor(0.0524)
#  layer  3 tensor(0.0554)
#  layer  4 tensor(0.3682)
# network number 5  :
#
#  layer 0 tensor(0.3187)
#  layer  1 tensor(0.0412)
#  layer  2 tensor(0.0274)
#  layer  3 tensor(0.0431)
#  layer  4 tensor(0.0649)
#  layer  5 tensor(0.3860)
# network number 6  :
#
#  layer 0 tensor(0.2411)
#  layer  1 tensor(0.0353)
#  layer  2 tensor(0.0583)
#  layer  3 tensor(0.0588)
#  layer  4 tensor(0.0349)
#  layer  5 tensor(0.0272)
#  layer  6 tensor(0.2904)
# network number 7  :
#
#  layer 0 tensor(0.2372)
#  layer  1 tensor(0.0857)
#  layer  2 tensor(0.0526)
#  layer  3 tensor(0.0553)
#  layer  4 tensor(0.0557)
#  layer  5 tensor(0.0698)
#  layer  6 tensor(0.0958)
#  layer  7 tensor(0.3586)
# network number 8  :
#
#  layer 0 tensor(0.1771)
#  layer  1 tensor(0.0861)
#  layer  2 tensor(0.0413)
#  layer  3 tensor(0.0284)
#  layer  4 tensor(0.0391)
#  layer  5 tensor(0.0324)
#  layer  6 tensor(0.0348)
#  layer  7 tensor(0.0556)
#  layer  8 tensor(0.3960)
# network number 9  :
#
#  layer 0 tensor(0.6221)
#  layer  1 tensor(0.1718)
#  layer  2 tensor(0.0517)
#  layer  3 tensor(0.1156)
#  layer  4 tensor(0.0422)
#  layer  5 tensor(0.2561)
#  layer  6 tensor(0.0362)
#  layer  7 tensor(0.0382)
#  layer  8 tensor(0.2479)
#  layer  9 tensor(0.3213)
# network number 10  :
#
#  layer 0 tensor(3.1671)
#  layer  1 tensor(0.2128)
#  layer  2 tensor(0.1083)
#  layer  3 tensor(0.1050)
#  layer  4 tensor(0.0696)
#  layer  5 tensor(0.1001)
#  layer  6 tensor(0.0689)
#  layer  7 tensor(0.1195)
#  layer  8 tensor(0.1329)
#  layer  9 tensor(0.4246)
#  layer  10 tensor(0.2094)
# network number 11  :
#
#  layer 0 tensor(0.1235)
#  layer  1 tensor(0.2559)
#  layer  2 tensor(0.3947)
#  layer  3 tensor(0.1857)
#  layer  4 tensor(0.0706)
#  layer  5 tensor(0.0290)
#  layer  6 tensor(0.0691)
#  layer  7 tensor(0.0312)
#  layer  8 tensor(0.0753)
#  layer  9 tensor(0.0877)
#  layer  10 tensor(0.0789)
#  layer  11 tensor(0.3601)
# network number 12  :
#
#  layer 0 tensor(0.6399)
#  layer  1 tensor(0.3951)
#  layer  2 tensor(0.1430)
#  layer  3 tensor(0.2199)
#  layer  4 tensor(0.0967)
#  layer  5 tensor(0.0458)
#  layer  6 tensor(0.0657)
#  layer  7 tensor(0.0567)
#  layer  8 tensor(0.0345)
#  layer  9 tensor(0.0614)
#  layer  10 tensor(0.0978)
#  layer  11 tensor(0.0149)
#  layer  12 tensor(0.1723)
# network number 13  :
#
#  layer 0 tensor(0.1751)
#  layer  1 tensor(0.2271)
#  layer  2 tensor(0.1209)
#  layer  3 tensor(0.2550)
#  layer  4 tensor(0.1435)
#  layer  5 tensor(0.0664)
#  layer  6 tensor(0.0306)
#  layer  7 tensor(0.0251)
#  layer  8 tensor(0.0228)
#  layer  9 tensor(0.0192)
#  layer  10 tensor(0.0240)
#  layer  11 tensor(0.0409)
#  layer  12 tensor(0.0590)
#  layer  13 tensor(0.1125)
# network number 14  :
#
#  layer 0 tensor(1.6724)
#  layer  1 tensor(1.1344)
#  layer  2 tensor(0.9973)
#  layer  3 tensor(0.9649)
#  layer  4 tensor(0.2232)
#  layer  5 tensor(0.1933)
#  layer  6 tensor(0.3374)
#  layer  7 tensor(0.1085)
#  layer  8 tensor(0.1460)
#  layer  9 tensor(0.0560)
#  layer  10 tensor(0.0707)
#  layer  11 tensor(0.2146)
#  layer  12 tensor(0.1413)
#  layer  13 tensor(0.2283)
#  layer  14 tensor(0.3192)
# network number 15  :
#
#  layer 0 tensor(14.6882)
#  layer  1 tensor(19.2220)
#  layer  2 tensor(7.1193)
#  layer  3 tensor(2.2870)
#  layer  4 tensor(0.9558)
#  layer  5 tensor(1.0333)
#  layer  6 tensor(1.4608)
#  layer  7 tensor(1.4409)
#  layer  8 tensor(0.9206)
#  layer  9 tensor(1.0201)
#  layer  10 tensor(0.4983)
#  layer  11 tensor(0.2764)
#  layer  12 tensor(0.2050)
#  layer  13 tensor(0.1202)
#  layer  14 tensor(0.0694)
#  layer  15 tensor(0.1728)
# network number 16  :
#
#  layer 0 tensor(0.6612)
#  layer  1 tensor(0.5936)
#  layer  2 tensor(0.2442)
#  layer  3 tensor(0.3276)
#  layer  4 tensor(0.2367)
#  layer  5 tensor(0.1353)
#  layer  6 tensor(0.0537)
#  layer  7 tensor(0.0251)
#  layer  8 tensor(0.0222)
#  layer  9 tensor(0.0327)
#  layer  10 tensor(0.0317)
#  layer  11 tensor(0.0171)
#  layer  12 tensor(0.0206)
#  layer  13 tensor(0.0067)
#  layer  14 tensor(0.0213)
#  layer  15 tensor(0.0338)
#  layer  16 tensor(0.3224)
# network number 17  :
#
#  layer 0 tensor(3.7172)
#  layer  1 tensor(1.6605)
#  layer  2 tensor(1.3661)
#  layer  3 tensor(1.5791)
#  layer  4 tensor(1.4828)
#  layer  5 tensor(1.0401)
#  layer  6 tensor(1.4990)
#  layer  7 tensor(1.5391)
#  layer  8 tensor(0.5654)
#  layer  9 tensor(0.6317)
#  layer  10 tensor(0.6334)
#  layer  11 tensor(0.2296)
#  layer  12 tensor(0.1139)
#  layer  13 tensor(0.0569)
#  layer  14 tensor(0.0628)
#  layer  15 tensor(0.0381)
#  layer  16 tensor(0.0309)
#  layer  17 tensor(0.2004)
# network number 18  :
#
#  layer 0 tensor(7.1293)
#  layer  1 tensor(7.7538)
#  layer  2 tensor(3.7046)
#  layer  3 tensor(0.7067)
#  layer  4 tensor(1.0895)
#  layer  5 tensor(0.5424)
#  layer  6 tensor(0.4451)
#  layer  7 tensor(0.2000)
#  layer  8 tensor(0.1458)
#  layer  9 tensor(0.3350)
#  layer  10 tensor(0.2596)
#  layer  11 tensor(0.1518)
#  layer  12 tensor(0.1402)
#  layer  13 tensor(0.0895)
#  layer  14 tensor(0.0810)
#  layer  15 tensor(0.0449)
#  layer  16 tensor(0.0245)
#  layer  17 tensor(0.0447)
#  layer  18 tensor(0.2268)
# network number 19  :
#
#  layer 0 tensor(10.1663)
#  layer  1 tensor(8.0276)
#  layer  2 tensor(2.0237)
#  layer  3 tensor(1.0836)
#  layer  4 tensor(1.4375)
#  layer  5 tensor(1.7249)
#  layer  6 tensor(0.8845)
#  layer  7 tensor(1.1606)
#  layer  8 tensor(0.1482)
#  layer  9 tensor(0.2963)
#  layer  10 tensor(0.0839)
#  layer  11 tensor(0.0944)
#  layer  12 tensor(0.0783)
#  layer  13 tensor(0.0662)
#  layer  14 tensor(0.0638)
#  layer  15 tensor(0.0901)
#  layer  16 tensor(0.0736)
#  layer  17 tensor(0.0639)
#  layer  18 tensor(0.0281)
#  layer  19 tensor(0.0444)
# network number 20  :
#
#  layer 0 tensor(21.6300)
#  layer  1 tensor(14.8121)
#  layer  2 tensor(4.0802)
#  layer  3 tensor(5.4363)
#  layer  4 tensor(1.7744)
#  layer  5 tensor(1.5212)
#  layer  6 tensor(0.8830)
#  layer  7 tensor(1.3899)
#  layer  8 tensor(0.8203)
#  layer  9 tensor(0.4696)
#  layer  10 tensor(0.3837)
#  layer  11 tensor(0.1956)
#  layer  12 tensor(0.3385)
#  layer  13 tensor(0.0377)
#  layer  14 tensor(0.0474)
#  layer  15 tensor(0.0544)
#  layer  16 tensor(0.0673)
#  layer  17 tensor(0.0334)
#  layer  18 tensor(0.0284)
#  layer  19 tensor(0.0567)
#  layer  20 tensor(0.0751)

# %% [markdown]
# استفاده از سیگموید باعث می شود با افزایش لایه ها ضرایب لایه های نخستین تضعیف شوند و اهمیت انها کمتر شود اما در رلو اینگونه نیست اگرچه کمی باز هم دیده می شود.

# %%
l=torch.tensor([[[1,2]] ,[[5,6]] , [[2 , 3]]])
print(l.shape)
print(torch.argmax(l , dim=2))
# Out:
# torch.Size([3, 1, 2])
# tensor([[1],
#         [1],
#         [1]])

# %%
 #batchnorm
max=20
##########################################
Active_Function=nn.ReLU()
print('with ',Active_Function,' active faunction:')
#################
for num_layers in range(1,max+1,1):
  q=[]
  train_losses , test_losses,  train_acc , test_acc  , model  = train(num_layers,LOSS,(X_train,y_train,X_test,y_test),num_epochs,model=Model3,showepochs=0,classes=classes)

  print('network number' ,num_layers, " : \n")

  print(' layer 0', torch.norm(model.input_layer.weight.grad))

  for j in range(1,num_layers,1):

    r="model.hidden."+"hidden_layer"+str(j-1)+".weight.grad"
    print(' layer ',j, torch.norm(eval(r)))

  print(' layer ',num_layers,torch.norm(model.output_layer.weight.grad))
# Out:
# with  ReLU()  active faunction:
# network number 1  :
#
#  layer 0 tensor(0.4292)
#  layer  1 tensor(0.2625)
# network number 2  :
#
#  layer 0 tensor(0.0612)
#  layer  1 tensor(0.1070)
#  layer  2 tensor(0.1893)
# network number 3  :
#
#  layer 0 tensor(0.0297)
#  layer  1 tensor(0.0161)
#  layer  2 tensor(0.0413)
#  layer  3 tensor(0.4938)
# network number 4  :
#
#  layer 0 tensor(0.1119)
#  layer  1 tensor(0.1237)
#  layer  2 tensor(0.0738)
#  layer  3 tensor(0.0666)
#  layer  4 tensor(0.3027)
# network number 5  :
#
#  layer 0 tensor(0.6773)
#  layer  1 tensor(0.7945)
#  layer  2 tensor(0.1000)
#  layer  3 tensor(0.0600)
#  layer  4 tensor(0.2562)
#  layer  5 tensor(0.0764)
# network number 6  :
#
#  layer 0 tensor(0.7436)
#  layer  1 tensor(0.0751)
#  layer  2 tensor(0.1817)
#  layer  3 tensor(0.0707)
#  layer  4 tensor(0.0424)
#  layer  5 tensor(0.0370)
#  layer  6 tensor(0.2013)
# network number 7  :
#
#  layer 0 tensor(0.1079)
#  layer  1 tensor(0.0402)
#  layer  2 tensor(0.0353)
#  layer  3 tensor(0.0341)
#  layer  4 tensor(0.0339)
#  layer  5 tensor(0.0399)
#  layer  6 tensor(0.0373)
#  layer  7 tensor(0.4338)
# network number 8  :
#
#  layer 0 tensor(1.5195)
#  layer  1 tensor(0.1394)
#  layer  2 tensor(0.1481)
#  layer  3 tensor(0.1136)
#  layer  4 tensor(0.0925)
#  layer  5 tensor(0.0677)
#  layer  6 tensor(0.1229)
#  layer  7 tensor(0.1827)
#  layer  8 tensor(0.2114)
# network number 9  :
#
#  layer 0 tensor(5.2835)
#  layer  1 tensor(0.2938)
#  layer  2 tensor(0.2718)
#  layer  3 tensor(0.1512)
#  layer  4 tensor(0.1887)
#  layer  5 tensor(0.0996)
#  layer  6 tensor(0.0955)
#  layer  7 tensor(0.0901)
#  layer  8 tensor(0.1085)
#  layer  9 tensor(0.2478)
# network number 10  :
#
#  layer 0 tensor(1.0562)
#  layer  1 tensor(0.1827)
#  layer  2 tensor(0.1061)
#  layer  3 tensor(0.0855)
#  layer  4 tensor(0.0459)
#  layer  5 tensor(0.0598)
#  layer  6 tensor(0.0521)
#  layer  7 tensor(0.0494)
#  layer  8 tensor(0.0505)
#  layer  9 tensor(0.0893)
#  layer  10 tensor(0.1739)
# network number 11  :
#
#  layer 0 tensor(0.9190)
#  layer  1 tensor(0.1807)
#  layer  2 tensor(0.0462)
#  layer  3 tensor(0.1043)
#  layer  4 tensor(0.1940)
#  layer  5 tensor(0.1480)
#  layer  6 tensor(0.2066)
#  layer  7 tensor(0.2143)
#  layer  8 tensor(0.0984)
#  layer  9 tensor(0.0554)
#  layer  10 tensor(0.0877)
#  layer  11 tensor(0.2169)
# network number 12  :
#
#  layer 0 tensor(4.9746)
#  layer  1 tensor(0.4892)
#  layer  2 tensor(0.4085)
#  layer  3 tensor(0.3502)
#  layer  4 tensor(0.4610)
#  layer  5 tensor(0.2173)
#  layer  6 tensor(0.2737)
#  layer  7 tensor(0.2718)
#  layer  8 tensor(0.1542)
#  layer  9 tensor(0.0675)
#  layer  10 tensor(0.0945)
#  layer  11 tensor(0.1955)
#  layer  12 tensor(0.1522)
# network number 13  :
#
#  layer 0 tensor(1.8750)
#  layer  1 tensor(0.4379)
#  layer  2 tensor(0.6330)
#  layer  3 tensor(0.3904)
#  layer  4 tensor(0.1394)
#  layer  5 tensor(0.1399)
#  layer  6 tensor(0.0738)
#  layer  7 tensor(0.1284)
#  layer  8 tensor(0.0440)
#  layer  9 tensor(0.0251)
#  layer  10 tensor(0.0375)
#  layer  11 tensor(0.0198)
#  layer  12 tensor(0.1155)
#  layer  13 tensor(0.3662)
# network number 14  :
#
#  layer 0 tensor(3.3224)
#  layer  1 tensor(0.5669)
#  layer  2 tensor(0.5805)
#  layer  3 tensor(0.7596)
#  layer  4 tensor(1.3808)
#  layer  5 tensor(0.4912)
#  layer  6 tensor(0.2094)
#  layer  7 tensor(0.4859)
#  layer  8 tensor(0.3824)
#  layer  9 tensor(0.2463)
#  layer  10 tensor(0.1566)
#  layer  11 tensor(0.1757)
#  layer  12 tensor(0.1207)
#  layer  13 tensor(0.1399)
#  layer  14 tensor(0.1306)
# network number 15  :
#
#  layer 0 tensor(11.5059)
#  layer  1 tensor(0.7281)
#  layer  2 tensor(1.5765)
#  layer  3 tensor(0.2971)
#  layer  4 tensor(0.3071)
#  layer  5 tensor(0.2510)
#  layer  6 tensor(0.1562)
#  layer  7 tensor(0.2007)
#  layer  8 tensor(0.5037)
#  layer  9 tensor(0.1733)
#  layer  10 tensor(0.0882)
#  layer  11 tensor(0.1649)
#  layer  12 tensor(0.0927)
#  layer  13 tensor(0.0861)
#  layer  14 tensor(0.1846)
#  layer  15 tensor(0.2568)
# network number 16  :
#
#  layer 0 tensor(4.9323)
#  layer  1 tensor(1.1514)
#  layer  2 tensor(0.9676)
#  layer  3 tensor(0.5064)
#  layer  4 tensor(0.7451)
#  layer  5 tensor(0.4944)
#  layer  6 tensor(0.3646)
#  layer  7 tensor(0.1747)
#  layer  8 tensor(0.1886)
#  layer  9 tensor(0.1495)
#  layer  10 tensor(0.0986)
#  layer  11 tensor(0.0458)
#  layer  12 tensor(0.1135)
#  layer  13 tensor(0.1625)
#  layer  14 tensor(0.1218)
#  layer  15 tensor(0.0669)
#  layer  16 tensor(0.2724)
# network number 17  :
#
#  layer 0 tensor(44.8918)
#  layer  1 tensor(4.3343)
#  layer  2 tensor(2.1493)
#  layer  3 tensor(1.8373)
#  layer  4 tensor(0.5184)
#  layer  5 tensor(0.7684)
#  layer  6 tensor(0.5065)
#  layer  7 tensor(0.5619)
#  layer  8 tensor(0.3347)
#  layer  9 tensor(0.1881)
#  layer  10 tensor(0.1538)
#  layer  11 tensor(0.1759)
#  layer  12 tensor(0.0468)
#  layer  13 tensor(0.0503)
#  layer  14 tensor(0.0457)
#  layer  15 tensor(0.0332)
#  layer  16 tensor(0.0469)
#  layer  17 tensor(0.2858)
# network number 18  :
#
#  layer 0 tensor(13.1343)
#  layer  1 tensor(8.0065)
#  layer  2 tensor(3.6967)
#  layer  3 tensor(2.8454)
#  layer  4 tensor(6.8160)
#  layer  5 tensor(1.6795)
#  layer  6 tensor(0.5590)
#  layer  7 tensor(1.2924)
#  layer  8 tensor(0.4004)
#  layer  9 tensor(0.3115)
#  layer  10 tensor(0.2881)
#  layer  11 tensor(0.1436)
#  layer  12 tensor(0.1095)
#  layer  13 tensor(0.1401)
#  layer  14 tensor(0.0522)
#  layer  15 tensor(0.0687)
#  layer  16 tensor(0.1469)
#  layer  17 tensor(0.1157)
#  layer  18 tensor(0.2726)
# network number 19  :
#
#  layer 0 tensor(21.0285)
#  layer  1 tensor(2.8978)
#  layer  2 tensor(2.9559)
#  layer  3 tensor(7.6688)
#  layer  4 tensor(3.0966)
#  layer  5 tensor(1.5736)
#  layer  6 tensor(0.6888)
#  layer  7 tensor(0.9190)
#  layer  8 tensor(0.1677)
#  layer  9 tensor(0.1503)
#  layer  10 tensor(0.2021)
#  layer  11 tensor(0.1666)
#  layer  12 tensor(0.2790)
#  layer  13 tensor(0.1302)
#  layer  14 tensor(0.1801)
#  layer  15 tensor(0.1297)
#  layer  16 tensor(0.0648)
#  layer  17 tensor(0.0495)
#  layer  18 tensor(0.1159)
#  layer  19 tensor(0.1779)
# network number 20  :
#
#  layer 0 tensor(6.8756)
#  layer  1 tensor(2.7573)
#  layer  2 tensor(2.7457)
#  layer  3 tensor(1.7480)
#  layer  4 tensor(2.1991)
#  layer  5 tensor(1.9962)
#  layer  6 tensor(0.8681)
#  layer  7 tensor(0.3652)
#  layer  8 tensor(0.2437)
#  layer  9 tensor(0.2767)
#  layer  10 tensor(0.2567)
#  layer  11 tensor(0.1519)
#  layer  12 tensor(0.1044)
#  layer  13 tensor(0.0849)
#  layer  14 tensor(0.1389)
#  layer  15 tensor(0.1474)
#  layer  16 tensor(0.2002)
#  layer  17 tensor(0.1543)
#  layer  18 tensor(0.0787)
#  layer  19 tensor(0.0690)
#  layer  20 tensor(0.0801)

# %%
 #batchnorm    # sigmoid
max=20
##########################################
Active_Function=nn.Sigmoid()
print('with ',Active_Function,' active faunction:')
#################
for num_layers in range(1,max+1,1):
  q=[]
  train_losses , test_losses,  train_acc , test_acc  , model  = train(num_layers,LOSS,(X_train,y_train,X_test,y_test),num_epochs,model=Model4,showepochs=0,classes=classes)

  print('network number' ,num_layers, " : \n")

  print(' layer 0', torch.norm(model.input_layer.weight.grad))

  for j in range(1,num_layers,1):

    r="model.hidden."+"hidden_layer"+str(j-1)+".weight.grad"
    print(' layer ',j, torch.norm(eval(r)))

  print(' layer ',num_layers,torch.norm(model.output_layer.weight.grad))
# Out:
# with  Sigmoid()  active faunction:
# network number 1  :
#
#  layer 0 tensor(2.1166)
#  layer  1 tensor(0.4166)
# network number 2  :
#
#  layer 0 tensor(0.3289)
#  layer  1 tensor(0.0958)
#  layer  2 tensor(0.1826)
# network number 3  :
#
#  layer 0 tensor(0.1287)
#  layer  1 tensor(0.0180)
#  layer  2 tensor(0.0138)
#  layer  3 tensor(0.4599)
# network number 4  :
#
#  layer 0 tensor(0.0700)
#  layer  1 tensor(0.0930)
#  layer  2 tensor(0.0374)
#  layer  3 tensor(0.0131)
#  layer  4 tensor(0.3907)
# network number 5  :
#
#  layer 0 tensor(0.1645)
#  layer  1 tensor(0.1932)
#  layer  2 tensor(0.0825)
#  layer  3 tensor(0.0476)
#  layer  4 tensor(0.0640)
#  layer  5 tensor(0.4347)
# network number 6  :
#
#  layer 0 tensor(0.1128)
#  layer  1 tensor(0.0177)
#  layer  2 tensor(0.0176)
#  layer  3 tensor(0.0291)
#  layer  4 tensor(0.0181)
#  layer  5 tensor(0.0326)
#  layer  6 tensor(0.2048)
# network number 7  :
#
#  layer 0 tensor(0.0215)
#  layer  1 tensor(0.0123)
#  layer  2 tensor(0.0071)
#  layer  3 tensor(0.0092)
#  layer  4 tensor(0.0100)
#  layer  5 tensor(0.0169)
#  layer  6 tensor(0.0482)
#  layer  7 tensor(0.2511)
# network number 8  :
#
#  layer 0 tensor(0.0750)
#  layer  1 tensor(0.0084)
#  layer  2 tensor(0.0214)
#  layer  3 tensor(0.0642)
#  layer  4 tensor(0.0217)
#  layer  5 tensor(0.0359)
#  layer  6 tensor(0.0453)
#  layer  7 tensor(0.0816)
#  layer  8 tensor(0.3226)
# network number 9  :
#
#  layer 0 tensor(0.0506)
#  layer  1 tensor(0.0905)
#  layer  2 tensor(0.0382)
#  layer  3 tensor(0.0466)
#  layer  4 tensor(0.0523)
#  layer  5 tensor(0.0160)
#  layer  6 tensor(0.0353)
#  layer  7 tensor(0.0373)
#  layer  8 tensor(0.0146)
#  layer  9 tensor(0.2620)
# network number 10  :
#
#  layer 0 tensor(0.0890)
#  layer  1 tensor(0.0328)
#  layer  2 tensor(0.0248)
#  layer  3 tensor(0.0542)
#  layer  4 tensor(0.0767)
#  layer  5 tensor(0.0946)
#  layer  6 tensor(0.0794)
#  layer  7 tensor(0.0952)
#  layer  8 tensor(0.0786)
#  layer  9 tensor(0.1172)
#  layer  10 tensor(0.2844)
# network number 11  :
#
#  layer 0 tensor(0.0544)
#  layer  1 tensor(0.0607)
#  layer  2 tensor(0.0102)
#  layer  3 tensor(0.0197)
#  layer  4 tensor(0.0163)
#  layer  5 tensor(0.0323)
#  layer  6 tensor(0.0102)
#  layer  7 tensor(0.0137)
#  layer  8 tensor(0.0096)
#  layer  9 tensor(0.0206)
#  layer  10 tensor(0.0512)
#  layer  11 tensor(0.2365)
# network number 12  :
#
#  layer 0 tensor(0.0309)
#  layer  1 tensor(0.0086)
#  layer  2 tensor(0.0181)
#  layer  3 tensor(0.0152)
#  layer  4 tensor(0.0147)
#  layer  5 tensor(0.0053)
#  layer  6 tensor(0.0151)
#  layer  7 tensor(0.0090)
#  layer  8 tensor(0.0125)
#  layer  9 tensor(0.0071)
#  layer  10 tensor(0.0249)
#  layer  11 tensor(0.0270)
#  layer  12 tensor(0.2101)
# network number 13  :
#
#  layer 0 tensor(0.0552)
#  layer  1 tensor(0.0278)
#  layer  2 tensor(0.0188)
#  layer  3 tensor(0.0441)
#  layer  4 tensor(0.0339)
#  layer  5 tensor(0.0405)
#  layer  6 tensor(0.0311)
#  layer  7 tensor(0.0232)
#  layer  8 tensor(0.0171)
#  layer  9 tensor(0.0119)
#  layer  10 tensor(0.0152)
#  layer  11 tensor(0.0108)
#  layer  12 tensor(0.0110)
#  layer  13 tensor(0.2952)
# network number 14  :
#
#  layer 0 tensor(0.0412)
#  layer  1 tensor(0.0087)
#  layer  2 tensor(0.0071)
#  layer  3 tensor(0.0078)
#  layer  4 tensor(0.0203)
#  layer  5 tensor(0.0322)
#  layer  6 tensor(0.0152)
#  layer  7 tensor(0.0111)
#  layer  8 tensor(0.0071)
#  layer  9 tensor(0.0172)
#  layer  10 tensor(0.0122)
#  layer  11 tensor(0.0144)
#  layer  12 tensor(0.0223)
#  layer  13 tensor(0.0387)
#  layer  14 tensor(0.2136)
# network number 15  :
#
#  layer 0 tensor(0.0337)
#  layer  1 tensor(0.0058)
#  layer  2 tensor(0.0066)
#  layer  3 tensor(0.0036)
#  layer  4 tensor(0.0054)
#  layer  5 tensor(0.0111)
#  layer  6 tensor(0.0075)
#  layer  7 tensor(0.0058)
#  layer  8 tensor(0.0060)
#  layer  9 tensor(0.0105)
#  layer  10 tensor(0.0141)
#  layer  11 tensor(0.0164)
#  layer  12 tensor(0.0187)
#  layer  13 tensor(0.0170)
#  layer  14 tensor(0.0245)
#  layer  15 tensor(0.2483)
# network number 16  :
#
#  layer 0 tensor(0.0567)
#  layer  1 tensor(0.0531)
#  layer  2 tensor(0.0125)
#  layer  3 tensor(0.0163)
#  layer  4 tensor(0.0489)
#  layer  5 tensor(0.1624)
#  layer  6 tensor(0.0597)
#  layer  7 tensor(0.0483)
#  layer  8 tensor(0.0307)
#  layer  9 tensor(0.0132)
#  layer  10 tensor(0.0188)
#  layer  11 tensor(0.0249)
#  layer  12 tensor(0.0261)
#  layer  13 tensor(0.0105)
#  layer  14 tensor(0.0140)
#  layer  15 tensor(0.0103)
#  layer  16 tensor(0.3460)
# network number 17  :
#
#  layer 0 tensor(0.0857)
#  layer  1 tensor(0.2319)
#  layer  2 tensor(0.0339)
#  layer  3 tensor(0.0818)
#  layer  4 tensor(0.0469)
#  layer  5 tensor(0.0638)
#  layer  6 tensor(0.0141)
#  layer  7 tensor(0.0241)
#  layer  8 tensor(0.0077)
#  layer  9 tensor(0.0323)
#  layer  10 tensor(0.0262)
#  layer  11 tensor(0.0203)
#  layer  12 tensor(0.0204)
#  layer  13 tensor(0.0153)
#  layer  14 tensor(0.0958)
#  layer  15 tensor(0.0945)
#  layer  16 tensor(0.1316)
#  layer  17 tensor(0.2100)
# network number 18  :
#
#  layer 0 tensor(0.0226)
#  layer  1 tensor(0.0140)
#  layer  2 tensor(0.0248)
#  layer  3 tensor(0.0155)
#  layer  4 tensor(0.0086)
#  layer  5 tensor(0.0099)
#  layer  6 tensor(0.0117)
#  layer  7 tensor(0.0093)
#  layer  8 tensor(0.0188)
#  layer  9 tensor(0.0241)
#  layer  10 tensor(0.0152)
#  layer  11 tensor(0.0176)
#  layer  12 tensor(0.0148)
#  layer  13 tensor(0.0113)
#  layer  14 tensor(0.0080)
#  layer  15 tensor(0.0226)
#  layer  16 tensor(0.0229)
#  layer  17 tensor(0.0437)
#  layer  18 tensor(0.2310)
# network number 19  :
#
#  layer 0 tensor(0.1156)
#  layer  1 tensor(0.1700)
#  layer  2 tensor(0.0618)
#  layer  3 tensor(0.0734)
#  layer  4 tensor(0.0548)
#  layer  5 tensor(0.0806)
#  layer  6 tensor(0.0257)
#  layer  7 tensor(0.0785)
#  layer  8 tensor(0.0398)
#  layer  9 tensor(0.0486)
#  layer  10 tensor(0.0822)
#  layer  11 tensor(0.0365)
#  layer  12 tensor(0.1566)
#  layer  13 tensor(0.1162)
#  layer  14 tensor(0.0706)
#  layer  15 tensor(0.0208)
#  layer  16 tensor(0.0197)
#  layer  17 tensor(0.0187)
#  layer  18 tensor(0.0139)
#  layer  19 tensor(0.2102)
# network number 20  :
#
#  layer 0 tensor(0.1413)
#  layer  1 tensor(0.0269)
#  layer  2 tensor(0.0083)
#  layer  3 tensor(0.0125)
#  layer  4 tensor(0.0052)
#  layer  5 tensor(0.0095)
#  layer  6 tensor(0.0096)
#  layer  7 tensor(0.0065)
#  layer  8 tensor(0.0054)
#  layer  9 tensor(0.0041)
#  layer  10 tensor(0.0072)
#  layer  11 tensor(0.0135)
#  layer  12 tensor(0.0155)
#  layer  13 tensor(0.0122)
#  layer  14 tensor(0.0069)
#  layer  15 tensor(0.0136)
#  layer  16 tensor(0.0140)
#  layer  17 tensor(0.0392)
#  layer  18 tensor(0.0223)
#  layer  19 tensor(0.0343)
#  layer  20 tensor(0.2651)
